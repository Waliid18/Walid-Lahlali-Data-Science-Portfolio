# %% [markdown]
# # Project 7 : DataFrame

# %% [markdown]
# 1. **Download the dataframe from the API call for Golden_State.**
#
# **url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl"**

# %%
import pandas as pd
import requests

def download(url , file) :
    rep = requests.get(url)
    if rep.status_code == 200 :
        with open (file,'wb') as f :
            f.write(rep.content)

url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl"
            
download(url , "Golden_State.pkl")
df = pd.read_pickle("Golden_State.pkl")
df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22019  1610612744               GSW  Golden State Warriors  1521900066
# 1     22019  1610612744               GSW  Golden State Warriors  1521900058
# 2     22019  1610612744               GSW  Golden State Warriors  1521900039
# 3     22019  1610612744               GSW  Golden State Warriors  1521900020
# 4     22019  1610612744               GSW  Golden State Warriors  1521900007
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2019-07-12  GSW vs. LAL  L  200   87  ...   0.800  13.0  29.0  42.0   13
# 1  2019-07-10    GSW @ DEN  W  201   73  ...   0.867   7.0  27.0  34.0   10
# 2  2019-07-08    GSW @ LAL  W  200   88  ...   0.621   8.0  29.0  37.0   21
# 3  2019-07-07  GSW vs. TOR  W  201   80  ...   0.923   6.0  37.0  43.0   18
# 4  2019-07-05  GSW vs. CHA  L  200   85  ...   0.889   8.0  28.0  36.0   19
#
#     STL  BLK   TOV  PF  PLUS_MINUS
# ...

# %%
print("Les informations de ce DataFrame :")
df.info()
# Out:
# Les informations de ce DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3238 entries, 0 to 3237
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_ID          3238 non-null   object
#  1   TEAM_ID            3238 non-null   int64
#  2   TEAM_ABBREVIATION  3238 non-null   object
#  3   TEAM_NAME          3238 non-null   object
#  4   GAME_ID            3238 non-null   object
#  5   GAME_DATE          3238 non-null   object
#  6   MATCHUP            3238 non-null   object
#  7   WL                 3237 non-null   object
#  8   MIN                3238 non-null   int64
#  9   PTS                3238 non-null   int64
#  10  FGM                3238 non-null   int64
#  11  FGA                3238 non-null   int64
#  12  FG_PCT             3237 non-null   float64
#  13  FG3M               3238 non-null   int64
#  14  FG3A               3236 non-null   float64
# ...

# %%
df.shape
# Out:
# (3238, 28)

# %% [markdown]
# 2.**Create two dataframes, one for the games that the Warriors faced the raptors at home, and the second for away games.**

# %%
# Firt dataframe
df_W_home = df[df["MATCHUP"] == "GSW vs. TOR"]

# %%
df_W_home
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 3        22019  1610612744               GSW  Golden State Warriors
# 8        42018  1610612744               GSW  Golden State Warriors
# 10       42018  1610612744               GSW  Golden State Warriors
# 11       42018  1610612744               GSW  Golden State Warriors
# 83       22018  1610612744               GSW  Golden State Warriors
# 223      22017  1610612744               GSW  Golden State Warriors
# 304      22016  1610612744               GSW  Golden State Warriors
# 444      22015  1610612744               GSW  Golden State Warriors
# 462      12015  1610612744               GSW  Golden State Warriors
# 541      22014  1610612744               GSW  Golden State Warriors
# 655      22013  1610612744               GSW  Golden State Warriors
# 721      22012  1610612744               GSW  Golden State Warriors
# 872      22010  1610612744               GSW  Golden State Warriors
# ...

# %%
# Second dataframe

df_W_away = df[df["MATCHUP"]=="GSW @ TOR"]

# %%
df_W_away
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 9        42018  1610612744               GSW  Golden State Warriors
# 12       42018  1610612744               GSW  Golden State Warriors
# 13       42018  1610612744               GSW  Golden State Warriors
# 89       22018  1610612744               GSW  Golden State Warriors
# 184      22017  1610612744               GSW  Golden State Warriors
# 326      22016  1610612744               GSW  Golden State Warriors
# 343      12016  1610612744               GSW  Golden State Warriors
# 345      22016  1610612744               GSW  Golden State Warriors
# 435      22015  1610612744               GSW  Golden State Warriors
# 516      22014  1610612744               GSW  Golden State Warriors
# 614      22013  1610612744               GSW  Golden State Warriors
# 738      22012  1610612744               GSW  Golden State Warriors
# 827      22011  1610612744               GSW  Golden State Warriors
# ...

# %% [markdown]
# 3.**Calculate the mean for the column PLUS_MINUS for the two dataframes home and  away**

# %%
df_W_home["PLUS_MINUS"].mean()
# Out:
# 3.730769230769231

# %%
print("The mean for the column PLUS_MINUS for the games that the Warriors faced the raptors at home is : ",df_W_home["PLUS_MINUS"].mean())
# Out:
# The mean for the column PLUS_MINUS for the games that the Warriors faced the raptors at home is :  3.730769230769231

# %%
print("The mean for the column PLUS_MINUS for the games that the Warriors faced the raptors away is : ",df_W_away["PLUS_MINUS"].mean())
# Out:
# The mean for the column PLUS_MINUS for the games that the Warriors faced the raptors away is :  -0.6071428571428571

# %% [markdown]
# 4. **Calculate the mean for the column PTS for the two dataframes home and  away:**

# %%
print("The mean for the column PTS for the games that the Warriors faced the raptors at home is : ",df_W_home['PTS'].mean())
# Out:
# The mean for the column PTS for the games that the Warriors faced the raptors at home is :  106.8076923076923

# %%
print("The mean for the column PTS for the games that the Warriors faced the raptors away is : ",df_W_away['PTS'].mean())
# Out:
# The mean for the column PTS for the games that the Warriors faced the raptors away is :  102.96428571428571

# %% [markdown]
# 5.**Plot out the PLUS MINUS column for the two dataframes home and away**

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

df_W_away.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
df_W_home.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
ax.legend(["away", "home"])
plt.show()

# %% [markdown]
# 6.**Plot out the PTS column for the two dataframes home and away**

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

df_W_home.plot (x = "GAME_DATE" , y = "PTS" , ax = ax)
df_W_away.plot (x= "GAME_DATE" , y = "PTS" , ax = ax)
ax.legend(["HOME","AWAY"])
plt.show()
